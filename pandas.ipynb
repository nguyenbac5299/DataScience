# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenbac5299/DataScience/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
#2 main datatypes
#series = 1-dimensional
series= pd.Series(['BMW', 'Toyota','Honda'])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
color= pd.Series(['red','blue','black'])

# %%
# DataFrame= 2-dimentional
car_data= pd.DataFrame({'Car make': series, 'Color': color})
car_data
# Out:
#   Car make  Color
# 0      BMW    red
# 1   Toyota   blue
# 2    Honda  black

# %%
 # Import data
 car_sales= pd.read_csv('/content/drive/MyDrive/ColabNotebooks/sources/DataScience/Data/data/7.1 car-sales.csv')
 car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a DataFrame
car_sales.to_csv('exported-car-sales.csv')

# %% [markdown]
# #Describe Data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info
# Out:
# <bound method DataFrame.info of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_sales.mean()
# Out:
# <ipython-input-14-04f02239622f>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# # Viewing and Selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#.loc & .iloc
animals= pd.Series(['cat', 'dog','bird','panda','snake'], index=[0,3,8,9,3])
animals
# Out:
# 0      cat
# 3      dog
# 8     bird
# 9    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 8    bird
# dtype: object

# %%
car_sales['Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales['Make']=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales['Make'],car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(car_sales['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(car_sales['Make'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales['Odometer (KM)'].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]= car_sales["Price"].str.replace('[\$\,\.]','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-8ec1b88a5abe> in <module>
# ----> 1 car_sales["Price"]= car_sales["Price"].str.replace('[\$\,\.]','').astype(int)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4      4
# 1   Honda    Red          87899      4      5
# 2  Toyota   Blue          32549      3      7
# 3     BMW  Black          11179      5     22
# 4  Nissan  White         213095      4     35
# 5  Toyota  Green          99213      4     45
# 6   Honda   Blue          45698      4     75
# 7   Honda   Blue          54738      4      7
# 8  Toyota  White          60000      4    625
# 9  Nissan  White          31600      4     97

# %%
car_sales['Price'].plot()

# %% [markdown]
# #Manipulating Data

# %%
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_missing= pd.read_csv('/content/drive/MyDrive/ColabNotebooks/sources/DataScience/Data/data/9.2 car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace= True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing= pd.read_csv('/content/drive/MyDrive/ColabNotebooks/sources/DataScience/Data/data/9.2 car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped= car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv('car_sales_missing_dropped.csv')

# %%
# Column from Series
seats_column = pd.Series([5,5,5,5,5])

# New column called seats
car_sales['Seats']= seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4      4    5.0
# 1   Honda    Red          87899      4      5    5.0
# 2  Toyota   Blue          32549      3      7    5.0
# 3     BMW  Black          11179      5     22    5.0
# 4  Nissan  White         213095      4     35    5.0
# 5  Toyota  Green          99213      4     45    NaN
# 6   Honda   Blue          45698      4     75    NaN
# 7   Honda   Blue          54738      4      7    NaN
# 8  Toyota  White          60000      4    625    NaN
# 9  Nissan  White          31600      4     97    NaN

# %%
car_sales.fillna(5.0, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4      4    5.0
# 1   Honda    Red          87899      4      5    5.0
# 2  Toyota   Blue          32549      3      7    5.0
# 3     BMW  Black          11179      5     22    5.0
# 4  Nissan  White         213095      4     35    5.0
# 5  Toyota  Green          99213      4     45    5.0
# 6   Honda   Blue          45698      4     75    5.0
# 7   Honda   Blue          54738      4      7    5.0
# 8  Toyota  White          60000      4    625    5.0
# 9  Nissan  White          31600      4     97    5.0

# %%
# Column from python list
fuel_economy=[7.5,9.2,5.0,9.6,8.7,4.7,7.6,8.7,3.0,4.5]
car_sales['Fuel per 100KM']= fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4      4    5.0             7.5
# 1   Honda    Red          87899      4      5    5.0             9.2
# 2  Toyota   Blue          32549      3      7    5.0             5.0
# 3     BMW  Black          11179      5     22    5.0             9.6
# 4  Nissan  White         213095      4     35    5.0             8.7
# 5  Toyota  Green          99213      4     45    5.0             4.7
# 6   Honda   Blue          45698      4     75    5.0             7.6
# 7   Honda   Blue          54738      4      7    5.0             8.7
# 8  Toyota  White          60000      4    625    5.0             3.0
# 9  Nissan  White          31600      4     97    5.0             4.5

# %%
car_sales['Total fuel used']= car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100KM']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4      4    5.0             7.5
# 1   Honda    Red          87899      4      5    5.0             9.2
# 2  Toyota   Blue          32549      3      7    5.0             5.0
# 3     BMW  Black          11179      5     22    5.0             9.6
# 4  Nissan  White         213095      4     35    5.0             8.7
# 5  Toyota  Green          99213      4     45    5.0             4.7
# 6   Honda   Blue          45698      4     75    5.0             7.6
# 7   Honda   Blue          54738      4      7    5.0             8.7
# 8  Toyota  White          60000      4    625    5.0             3.0
# 9  Nissan  White          31600      4     97    5.0             4.5
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         4663.011
# 6         3473.048
# 7         4762.206
# 8         1800.000
# ...

# %%
car_sales['Number of wheels']=4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4      4    5.0             7.5
# 1   Honda    Red          87899      4      5    5.0             9.2
# 2  Toyota   Blue          32549      3      7    5.0             5.0
# 3     BMW  Black          11179      5     22    5.0             9.6
# 4  Nissan  White         213095      4     35    5.0             8.7
# 5  Toyota  Green          99213      4     45    5.0             4.7
# 6   Honda   Blue          45698      4     75    5.0             7.6
# 7   Honda   Blue          54738      4      7    5.0             8.7
# 8  Toyota  White          60000      4    625    5.0             3.0
# 9  Nissan  White          31600      4     97    5.0             4.5
#
#    Total fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# 3         1073.184                 4
# ...

# %%
car_sales['Passed road safety']= True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4      4    5.0             7.5
# 1   Honda    Red          87899      4      5    5.0             9.2
# 2  Toyota   Blue          32549      3      7    5.0             5.0
# 3     BMW  Black          11179      5     22    5.0             9.6
# 4  Nissan  White         213095      4     35    5.0             8.7
# 5  Toyota  Green          99213      4     45    5.0             4.7
# 6   Honda   Blue          45698      4     75    5.0             7.6
# 7   Honda   Blue          54738      4      7    5.0             8.7
# 8  Toyota  White          60000      4    625    5.0             3.0
# 9  Nissan  White          31600      4     97    5.0             4.5
#
#    Total fuel used  Number of wheels  Passed road safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
car_sales.drop('Total fuel used', axis=1, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4      4    5.0             7.5
# 1   Honda    Red          87899      4      5    5.0             9.2
# 2  Toyota   Blue          32549      3      7    5.0             5.0
# 3     BMW  Black          11179      5     22    5.0             9.6
# 4  Nissan  White         213095      4     35    5.0             8.7
# 5  Toyota  Green          99213      4     45    5.0             4.7
# 6   Honda   Blue          45698      4     75    5.0             7.6
# 7   Honda   Blue          54738      4      7    5.0             8.7
# 8  Toyota  White          60000      4    625    5.0             3.0
# 9  Nissan  White          31600      4     97    5.0             4.5
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# ...

# %%
car_sales_shuffled= car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 9  Nissan  White          31600      4     97    5.0             4.5
# 8  Toyota  White          60000      4    625    5.0             3.0
# 0  Toyota  White         150043      4      4    5.0             7.5
# 4  Nissan  White         213095      4     35    5.0             8.7
# 6   Honda   Blue          45698      4     75    5.0             7.6
# 7   Honda   Blue          54738      4      7    5.0             8.7
# 5  Toyota  Green          99213      4     45    5.0             4.7
# 1   Honda    Red          87899      4      5    5.0             9.2
# 3     BMW  Black          11179      5     22    5.0             9.6
# 2  Toyota   Blue          32549      3      7    5.0             5.0
#
#    Number of wheels  Passed road safety
# 9                 4                True
# 8                 4                True
# 0                 4                True
# 4                 4                True
# ...

# %%
# Only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 8  Toyota  White          60000      4    625    5.0             3.0
# 5  Toyota  Green          99213      4     45    5.0             4.7
#
#    Number of wheels  Passed road safety
# 8                 4                True
# 5                 4                True

# %%
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0      9  Nissan  White          31600      4     97    5.0             4.5
# 1      8  Toyota  White          60000      4    625    5.0             3.0
# 2      0  Toyota  White         150043      4      4    5.0             7.5
# 3      4  Nissan  White         213095      4     35    5.0             8.7
# 4      6   Honda   Blue          45698      4     75    5.0             7.6
# 5      7   Honda   Blue          54738      4      7    5.0             8.7
# 6      5  Toyota  Green          99213      4     45    5.0             4.7
# 7      1   Honda    Red          87899      4      5    5.0             9.2
# 8      3     BMW  Black          11179      5     22    5.0             9.6
# 9      2  Toyota   Blue          32549      3      7    5.0             5.0
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# ...

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Nissan  White          31600      4     97    5.0             4.5
# 1  Toyota  White          60000      4    625    5.0             3.0
# 2  Toyota  White         150043      4      4    5.0             7.5
# 3  Nissan  White         213095      4     35    5.0             8.7
# 4   Honda   Blue          45698      4     75    5.0             7.6
# 5   Honda   Blue          54738      4      7    5.0             8.7
# 6  Toyota  Green          99213      4     45    5.0             4.7
# 7   Honda    Red          87899      4      5    5.0             9.2
# 8     BMW  Black          11179      5     22    5.0             9.6
# 9  Toyota   Blue          32549      3      7    5.0             5.0
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4      4    5.0             7.5
# 1   Honda    Red          87899      4      5    5.0             9.2
# 2  Toyota   Blue          32549      3      7    5.0             5.0
# 3     BMW  Black          11179      5     22    5.0             9.6
# 4  Nissan  White         213095      4     35    5.0             8.7
# 5  Toyota  Green          99213      4     45    5.0             4.7
# 6   Honda   Blue          45698      4     75    5.0             7.6
# 7   Honda   Blue          54738      4      7    5.0             8.7
# 8  Toyota  White          60000      4    625    5.0             3.0
# 9  Nissan  White          31600      4     97    5.0             4.5
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# ...

# %%
car_sales['Odometer (KM)']= car_sales['Odometer (KM)'].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White      93776.875      4      4    5.0             7.5
# 1   Honda    Red      54936.875      4      5    5.0             9.2
# 2  Toyota   Blue      20343.125      3      7    5.0             5.0
# 3     BMW  Black       6986.875      5     22    5.0             9.6
# 4  Nissan  White     133184.375      4     35    5.0             8.7
# 5  Toyota  Green      62008.125      4     45    5.0             4.7
# 6   Honda   Blue      28561.250      4     75    5.0             7.6
# 7   Honda   Blue      34211.250      4      7    5.0             8.7
# 8  Toyota  White      37500.000      4    625    5.0             3.0
# 9  Nissan  White      19750.000      4     97    5.0             4.5
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# ...

# %%
car_sales.rename(columns={'Odometer (KM)': 'Odometer (Miles)'})
# Out:
#      Make Colour  Odometer (Miles)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         93776.875      4      4    5.0             7.5
# 1   Honda    Red         54936.875      4      5    5.0             9.2
# 2  Toyota   Blue         20343.125      3      7    5.0             5.0
# 3     BMW  Black          6986.875      5     22    5.0             9.6
# 4  Nissan  White        133184.375      4     35    5.0             8.7
# 5  Toyota  Green         62008.125      4     45    5.0             4.7
# 6   Honda   Blue         28561.250      4     75    5.0             7.6
# 7   Honda   Blue         34211.250      4      7    5.0             8.7
# 8  Toyota  White         37500.000      4    625    5.0             3.0
# 9  Nissan  White         19750.000      4     97    5.0             4.5
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...
